# %%
import config
import requests
import json

# %%
Authentic_api_key ='bc0a02c1dddea2b12aba42e7fbee9e69'

# %%
base_url = 'https://authenticjobs.com/api/'
params = {'api_key': Authentic_api_key,
          'format': 'json',
          'job_id':"id"
          }

# %%
params['method'] = 'aj.types.getList'
types = requests.get(base_url, params).json()
print(json.dumps(types,  indent=3))
# Out:
# {
#    "types": {
#       "type": [
#          {
#             "id": "1",
#             "name": "Full-time"
#          },
#          {
#             "id": "5",
#             "name": "Part-time"
#          }
#       ]
#    },
#    "stat": "ok"
# }

# %%
params['method'] = 'aj.categories.getList'
categories = requests.get(base_url, params).json()
print(json.dumps(categories,  indent=3))
# Out:
# {
#    "categories": {
#       "category": [
#          {
#             "id": "3",
#             "name": "Design &amp; User Experience"
#          },
#          {
#             "id": "4",
#             "name": "Front-end Engineering"
#          },
#          {
#             "id": "2",
#             "name": "Back-end Engineering"
#          },
#          {
#             "id": "5",
#             "name": "Apps"
#          },
#          {
#             "id": "10",
#             "name": "Product Management"
#          },
#          {
#             "id": "12",
#             "name": "Content &amp; Copywriting"
#          },
#          {
#             "id": "8",
#             "name": "Marketing &amp; Sales"
#          },
#          {
#             "id": "11",
#             "name": "Customer &amp; Community"
#          },
#          {
#             "id": "6",
#             "name": "Management"
#          },
#          {
#             "id": "9",
#             "name": "Miscellaneous"
#          }
#       ]
#    },
#    "stat": "ok"
# }

# %%
params['method'] = 'aj.jobs.getCompanies'
companies = requests.get(base_url, params).json()
print(json.dumps(companies,  indent=3))
# Out:
# {
#    "companies": {
#       "company": [
#          {
#             "id": "accomplice",
#             "name": "Accomplice",
#             "url": "https://accpl.co/",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": "Driving Digital & Organizational Success",
#             "location": {
#                "id": "austintxus",
#                "name": "Washington, DC",
#                "city": "Austin",
#                "country": "US",
#                "lat": "30.2672",
#                "lng": "-97.7431",
#                "state": "TX"
#             },
#             "count": 1
#          },
#          {
#             "id": "advicepay",
#             "name": "AdvicePay",
#             "url": "http://advicepay.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/2901db334bdbf06c0b30174eb5148630/thumb/Screen Shot 2018-06-20 at 11.12.58 AM.png",
#             "tagline": "Payment for Financial Advisors Made Easy",
#             "location": {
#                "id": "bozemanmtus",
#                "name": "Washington, DC",
#                "city": "Bozeman",
#                "country": "US",
#                "lat": "45.6796",
#                "lng": "-111.039",
#                "state": "MT"
#             },
#             "count": 1
#          },
#          {
#             "id": "aha",
#             "name": "Aha!",
#             "url": "http://aha.io",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/eda9f059c97616a9f098bc2b33a5ce6a/thumb/logo_blue square.png",
#             "tagline": "The world's #1 product roadmap software",
#             "location": {
#                "id": "anywhereinunitedstates",
#                "name": "Anywhere in United States"
#             },
#             "count": 1
#          },
#          {
#             "id": "archonsystems",
#             "name": "Archon Systems",
#             "url": "http://archonsystems.com/",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com1thumb/1",
#             "tagline": "Beautiful inventory software with 1+ million installs.",
#             "location": {
#                "id": "torontoca",
#                "name": "Washington, DC",
#                "city": "Toronto",
#                "country": "CA",
#                "lat": "43.7001",
#                "lng": "-79.4163"
#             },
#             "count": 1
#          },
#          {
#             "id": "arthouse",
#             "name": "ArtHouse",
#             "url": "http://arthousenewyork.com/",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/880b6605dc5d7002ba3b883e3881979a/thumb/D-G0bT9O_400x400.png",
#             "tagline": null,
#             "count": 1
#          },
#          {
#             "id": "audienceops",
#             "name": "Audience Ops",
#             "url": "http://audienceops.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/c592e886095ae12220a4d7a564823486/thumb/audience-ops-icon-square.jpg",
#             "tagline": "Quality content.  Quality team.  Quality clients.",
#             "location": {
#                "id": "unitedstates",
#                "name": "United States"
#             },
#             "count": 1
#          },
#          {
#             "id": "braid",
#             "name": "Braid",
#             "url": "https://wearebraid.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/b1b334db1f4f022c280bc6cbf4564384/thumb/braid_B_small.png",
#             "tagline": "A developer-led agency bringing digital innovations to market.",
#             "location": {
#                "id": "charlottesvilleva",
#                "name": "Charlottesville, VA"
#             },
#             "count": 2
#          },
#          {
#             "id": "brainstormcreativeresourcesdcbasedrecruiter",
#             "name": "Brainstorm Creative Resources (DC-based recruiter)",
#             "url": "https://brainstormresources.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/47e9766c3cae769d99ee83d214a863d1/thumb/0_NMxjWN0DCR_kO7FrQpURt_rxE.png",
#             "tagline": "Placing mid- and senior-level design professionals in DC since 2003.",
#             "location": {
#                "id": "washingtondcus",
#                "name": "Washington, DC",
#                "city": "Washington",
#                "country": "US",
#                "lat": "38.8951",
#                "lng": "-77.0364",
#                "state": "DC"
#             },
#             "count": 1
#          },
#          {
#             "id": "canva",
#             "name": "Canva",
#             "url": "https://about.canva.com/",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/97f20696c035cb91e3161b704a96f664/thumb/canva logo1.jpg",
#             "tagline": "Empowering the world to design.",
#             "location": {
#                "id": "sydneyau",
#                "name": "Washington, DC",
#                "city": "Sydney",
#                "country": "AU",
#                "lat": "-33.8679",
#                "lng": "151.207"
#             },
#             "count": 1
#          },
#          {
#             "id": "chalk",
#             "name": "Chalk",
#             "url": "http://madebychalk.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/482f235e29bafeb67f6e514f282bf96a/thumb/chalk-logo-2@2x.png",
#             "tagline": "Brand and Web Development for the Craft Brewing Industry",
#             "location": {
#                "id": "denvercous",
#                "name": "Washington, DC",
#                "city": "Denver",
#                "country": "US",
#                "lat": "39.7392",
#                "lng": "-104.985",
#                "state": "CO"
#             },
#             "count": 1
#          },
#          {
#             "id": "collegeofthesequoias",
#             "name": "College of the Sequoias",
#             "url": "http://www.cos.edu",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": "N/A",
#             "location": {
#                "id": "visaliacaus",
#                "name": "Washington, DC",
#                "city": "Visalia",
#                "country": "US",
#                "lat": "36.3302",
#                "lng": "-119.292",
#                "state": "CA"
#             },
#             "count": 1
#          },
#          {
#             "id": "congressionalbudgetoffice",
#             "name": "CONGRESSIONAL BUDGET OFFICE",
#             "url": "http://www.cbo.gov",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/logos/congressionalbudgetoffice_1395924412.png",
#             "tagline": "The Congressional Budget Office (CBO) is a small nonpartisan",
#             "location": {
#                "id": "washingtondc",
#                "name": "Washington, DC"
#             },
#             "count": 1
#          },
#          {
#             "id": "cunyschoolofjournalism",
#             "name": "CUNY School of Journalism",
#             "url": "http://",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": null,
#             "location": {
#                "id": "newyorknyus",
#                "name": "Washington, DC",
#                "city": "New York",
#                "country": "US",
#                "lat": "40.7143",
#                "lng": "-74.006",
#                "state": "NY"
#             },
#             "count": 1
#          },
#          {
#             "id": "dockyard",
#             "name": "DockYard",
#             "url": "https://dockyard.com/",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/9fd67642c75dab3370ce140265d2a7d8/thumb/DockYard_Badge_Digital_black.png",
#             "tagline": "We help ambitious companies transform new ideas into amazing web apps.",
#             "location": {
#                "id": "anywhereusonly",
#                "name": "Anywhere, US only"
#             },
#             "count": 1
#          },
#          {
#             "id": "egencia",
#             "name": "Egencia",
#             "url": "http://www.egencia.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/d24459163442c66700502b1ecdbcf377/thumb/Asset 2.png",
#             "tagline": "We design business travel products loved by over 8 million users.",
#             "location": {
#                "id": "bellevuewa",
#                "name": "Bellevue, WA"
#             },
#             "count": 1
#          },
#          {
#             "id": "epicenterconsulting",
#             "name": "Epicenter Consulting",
#             "url": "http://www.epicenterconsultin.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": "An obsessively thorough web application design and strategy firm.",
#             "location": {
#                "id": "anywhereuscanada",
#                "name": "Anywhere (US/Canada)"
#             },
#             "count": 1
#          },
#          {
#             "id": "esoftwareassociatesinc",
#             "name": "eSoftware Associates, Inc.",
#             "url": "http://www.eswcompany.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": "Customize the best business software to meet the needs of our clients.",
#             "location": {
#                "id": "anywhereus",
#                "name": "Anywhere, US"
#             },
#             "count": 1
#          },
#          {
#             "id": "everythingbutthehouse",
#             "name": "Everything But The House",
#             "url": "https://www.ebth.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/184f4c624a961715d42500988e1c865e/thumb/eSepM5s2_400x400.jpg",
#             "tagline": "EBTH is the world\u2019s premier marketplace for one-of-a-kind items.",
#             "location": {
#                "id": "cincinnatiohus",
#                "name": "Washington, DC",
#                "city": "Cincinnati",
#                "country": "US",
#                "lat": "39.1271",
#                "lng": "-84.5144",
#                "state": "OH"
#             },
#             "count": 2
#          },
#          {
#             "id": "evolutioncompany",
#             "name": "Evolution Company",
#             "url": "https://evolution-company.breezy.hr/p/98d3ecb31129-ux-ui-designer?source=authenticjobs",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/b25abc43ec116b423c7693a7f9fc1954/thumb/evolution company logo.png",
#             "tagline": "Build cutting edge saas products with us!",
#             "location": {
#                "id": "kalamazoomius",
#                "name": "Washington, DC",
#                "city": "Kalamazoo",
#                "country": "US",
#                "lat": "42.2917",
#                "lng": "-85.5872",
#                "state": "MI"
#             },
#             "count": 1
#          },
#          {
#             "id": "fleetsternextgenerationmobilitygmbhcokg",
#             "name": "fleetster | Next Generation Mobility GmbH & Co. KG",
#             "url": "http://www.fleetster.net",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/941e38f0d66707c14bfc4d413a51c08c/thumb/fleetster.png",
#             "tagline": "Carsharing Software // Mobility Plattform // Fleet Management // B2B",
#             "location": {
#                "id": "munichgermany",
#                "name": "Munich, Germany"
#             },
#             "count": 1
#          },
#          {
#             "id": "georgewbushpresidentialcenter",
#             "name": "George W. Bush Presidential Center",
#             "url": "http://www.bushcenter.org",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": null,
#             "location": {
#                "id": "dallastxus",
#                "name": "Washington, DC",
#                "city": "Dallas",
#                "country": "US",
#                "lat": "32.7831",
#                "lng": "-96.8067",
#                "state": "TX"
#             },
#             "count": 1
#          },
#          {
#             "id": "graphos",
#             "name": "Graphos",
#             "url": "http://www.graphos.ca",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/logos/graphos_1390520106.png",
#             "tagline": "Be where it's going. Work with Graphos!",
#             "location": {
#                "id": "edmontonabcanada",
#                "name": "Edmonton, AB, Canada"
#             },
#             "count": 1
#          },
#          {
#             "id": "griflandesigninc",
#             "name": "Griflan Design, Inc.",
#             "url": "http://www.griflan.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/989c421784448efc86c8747c9f38073f/thumb/12963948_1050753405017393_3761925052686744607_n.png",
#             "tagline": "A Creative Agency in Philadelphia, PA",
#             "location": {
#                "id": "unitedstates",
#                "name": "United States"
#             },
#             "count": 1
#          },
#          {
#             "id": "grove",
#             "name": "Grove",
#             "url": "https://www.thesourcery.com/job-seekers/?gh_jid=1201665",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": null,
#             "location": {
#                "id": "sanfranciscocaus",
#                "name": "Washington, DC",
#                "city": "San Francisco",
#                "country": "US",
#                "lat": "37.7749",
#                "lng": "-122.419",
#                "state": "CA"
#             },
#             "count": 4
#          },
#          {
#             "id": "grow",
#             "name": "Grow",
#             "url": "http://www.thisisgrow.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/e63424932eb843dd53920f00a2e771cb/thumb/0.png",
#             "tagline": "Grow is a digital agency for pioneering brands.",
#             "location": {
#                "id": "norfolkva",
#                "name": "Norfolk, VA"
#             },
#             "count": 1
#          },
#          {
#             "id": "iconworldwide",
#             "name": "ICON Worldwide",
#             "url": "http://www.icon-worldwide.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/0c10f11b24e1fd8d243a0fe591a47362/thumb/icon_facebook_logo.jpg",
#             "tagline": "Big Ideas Are Built Here",
#             "location": {
#                "id": "zrichswitzerland",
#                "name": "Z\u00fcrich, Switzerland"
#             },
#             "count": 1
#          },
#          {
#             "id": "iostudio",
#             "name": "iostudio",
#             "url": "http://www.iostudio.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": "Rebellious Creativity. Measurable Results",
#             "location": {
#                "id": "nashvilletnus",
#                "name": "Washington, DC",
#                "city": "Nashville",
#                "country": "US",
#                "lat": "36.1659",
#                "lng": "-86.7844",
#                "state": "TN"
#             },
#             "count": 1
#          },
#          {
#             "id": "iphonephotographyschool",
#             "name": "iPhone Photography School",
#             "url": "https://iphonephotographyschool.com/developer/?utm_source=authenticjobs",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/f16401eace0341b6fa416c096ca44a3c/thumb/iPS square logo.jpg",
#             "tagline": "The Best In Photography Education",
#             "count": 2
#          },
#          {
#             "id": "kaikaikiki",
#             "name": "Kaikai Kiki",
#             "url": "http://english.kaikaikiki.co.jp/",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/a92bed811e105e8df6895ccfdeacddf0/thumb/Screenshot 2018-06-26 10.36.53.png",
#             "tagline": "Japanese fine arts company coordinating worldwide exhibitions.",
#             "location": {
#                "id": "seattlewaus",
#                "name": "Washington, DC",
#                "city": "Seattle",
#                "country": "US",
#                "lat": "47.6062",
#                "lng": "-122.332",
#                "state": "WA"
#             },
#             "count": 1
#          },
#          {
#             "id": "leftright",
#             "name": "Left+Right",
#             "url": "http://leftplusright.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/logos/leftright_1398275122.png",
#             "tagline": "We build business through great software",
#             "count": 1
#          },
#          {
#             "id": "lewiscommunications",
#             "name": "Lewis Communications",
#             "url": "https://www.lewiscommunications.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com1thumb/1",
#             "tagline": "We create attention and trust for ideas we believe in.",
#             "location": {
#                "id": "nashvilletnus",
#                "name": "Washington, DC",
#                "city": "Nashville",
#                "country": "US",
#                "lat": "36.1659",
#                "lng": "-86.7844",
#                "state": "TN"
#             },
#             "count": 1
#          },
#          {
#             "id": "lillypulitzer",
#             "name": "Lilly Pulitzer",
#             "url": "http://www.lillypulitzer.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": "Apparel company located in King of Prussia, PA!",
#             "location": {
#                "id": "kingofprussiapaus",
#                "name": "Washington, DC",
#                "city": "King of Prussia",
#                "country": "US",
#                "lat": "40.0893",
#                "lng": "-75.396",
#                "state": "PA"
#             },
#             "count": 2
#          },
#          {
#             "id": "massachusettsinstituteoftechnologymit",
#             "name": "Massachusetts Institute of Technology (MIT)",
#             "url": "http://",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": null,
#             "location": {
#                "id": "cambridgema",
#                "name": "Cambridge, MA"
#             },
#             "count": 1
#          },
#          {
#             "id": "matador",
#             "name": "Matador",
#             "url": "http://matadorapp.com/",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/3f8a45ab3ba1a12f0c2902dec958bb19/thumb/Matador 2.0 logo.png",
#             "tagline": "The social investing app that lets you invest in stocks with friends.",
#             "location": {
#                "id": "newyorkcity",
#                "name": "New York City"
#             },
#             "count": 1
#          },
#          {
#             "id": "milkshakestudio",
#             "name": "Milkshake Studio",
#             "url": "http://milkshak.es",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/5530b557b5009d5a9a06a23668416d76/thumb/icon-more-space.jpg",
#             "tagline": "We're a creative studio focused on product design and branding.",
#             "location": {
#                "id": "newyorkcity",
#                "name": "New York City"
#             },
#             "count": 1
#          },
#          {
#             "id": "mindsondesignlab",
#             "name": "Minds On Design Lab",
#             "url": "https://mod-lab.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/c758e4667a5812c3230d54aeea7ece77/thumb/mod_logo_orange_circ)rgb@2x.png",
#             "tagline": "A design and digital team for the social good sector.",
#             "location": {
#                "id": "anywhereus",
#                "name": "Anywhere (US)"
#             },
#             "count": 1
#          },
#          {
#             "id": "mpc",
#             "name": "MPC",
#             "url": "http://www.moving-picture.com/",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/47e9766c3cae769d99ee83d214a863d1/thumb/CdqTtB7z_400x400.jpg",
#             "tagline": "We craft spectacular visual experiences in any space, on any screen.",
#             "location": {
#                "id": "londongb",
#                "name": "Washington, DC",
#                "city": "London",
#                "country": "GB",
#                "lat": "51.5085",
#                "lng": "-0.12574"
#             },
#             "count": 1
#          },
#          {
#             "id": "ncstateuniversity",
#             "name": "NC State University",
#             "url": "https://university-communications.ncsu.edu",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/logos/ncstateuniversity_1398265751.png",
#             "tagline": "Think and Do",
#             "location": {
#                "id": "raleighnc",
#                "name": "Raleigh, NC"
#             },
#             "count": 1
#          },
#          {
#             "id": "nellestranslations",
#             "name": "Nelles Translations",
#             "url": "http://nellestranslations.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/d8ec9c72a43e37cc6a37d65698b90f28/thumb/Wanted.jpg",
#             "tagline": "fun loving translation company needs hunter to grow to the next level",
#             "location": {
#                "id": "courtyardbymarriottchicagodowntownilus",
#                "name": "Washington, DC",
#                "city": "Courtyard by Marriott Chicago Downtown",
#                "country": "US",
#                "lat": "41.89",
#                "lng": "-87.6273",
#                "state": "IL"
#             },
#             "count": 1
#          },
#          {
#             "id": "slack",
#             "name": "Slack",
#             "url": "http://www.slack.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": null,
#             "location": {
#                "id": "sanfranciscocaus",
#                "name": "Washington, DC",
#                "city": "San Francisco",
#                "country": "US",
#                "lat": "37.7749",
#                "lng": "-122.419",
#                "state": "CA"
#             },
#             "count": 1
#          },
#          {
#             "id": "smartbugmedia",
#             "name": "SmartBug Media",
#             "url": "http://www.smartbugmedia.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": "Award-winning agency, 100% remote, 50+ emps, 70+ awards last year.",
#             "count": 1
#          },
#          {
#             "id": "stridersportsinternational",
#             "name": "Strider Sports International",
#             "url": "http://www.striderbikes.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": "Bikes without pedals that teach kids how to be incredibly awesome",
#             "location": {
#                "id": "rapidcitysdus",
#                "name": "Washington, DC",
#                "city": "Rapid City",
#                "country": "US",
#                "lat": "44.0805",
#                "lng": "-103.231",
#                "state": "SD"
#             },
#             "count": 1
#          },
#          {
#             "id": "studiosimpatico",
#             "name": "Studio Simpatico",
#             "url": "http://www.studiosimpati.co",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/be57812817829ca108c91db1a8a4f6fa/thumb/U2O6-Xkl_400x400.jpg",
#             "tagline": "A small, UX-driven design and digital studio based in Manhattan",
#             "location": {
#                "id": "newyorkny",
#                "name": "New York, NY"
#             },
#             "count": 1
#          },
#          {
#             "id": "thepinkstongroup",
#             "name": "The Pinkston Group",
#             "url": "https://www.pinkstondigital.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": "Opportunity to grow quickly into a director role.",
#             "location": {
#                "id": "alexandriavaus",
#                "name": "Washington, DC",
#                "city": "Alexandria",
#                "country": "US",
#                "lat": "38.8048",
#                "lng": "-77.0469",
#                "state": "VA"
#             },
#             "count": 1
#          },
#          {
#             "id": "thinkcompanyinc",
#             "name": "Think Company, Inc.",
#             "url": "http://www.thinkcompany.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com1thumb/1",
#             "tagline": "Experience Design, Research & Strategy, Software Development",
#             "location": {
#                "id": "philadelphiapaus",
#                "name": "Washington, DC",
#                "city": "Philadelphia",
#                "country": "US",
#                "lat": "39.9523",
#                "lng": "-75.1638",
#                "state": "PA"
#             },
#             "count": 2
#          },
#          {
#             "id": "thunder",
#             "name": "Thunder",
#             "url": "http://www.makethunder.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/b1010dcfa3e9384fb4bb1b3deb2f335d/thumb/bolt-500x500.png",
#             "tagline": "Building the future of advertising",
#             "location": {
#                "id": "seattle",
#                "name": "Seattle"
#             },
#             "count": 1
#          },
#          {
#             "id": "trustmarknationalbank",
#             "name": "Trustmark National Bank",
#             "url": "https://www.trustmark.com/",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/572a79e1c1b902c80db686a89e09d22c/thumb/Trustmark_Logo_431_Grey.jpg.jpg",
#             "tagline": "People you trust. Advice that works.",
#             "location": {
#                "id": "jacksonms",
#                "name": "Jackson, MS"
#             },
#             "count": 2
#          },
#          {
#             "id": "typecode",
#             "name": "Type/Code",
#             "url": "http://typecode.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/logos/typecode_1378761978.png",
#             "tagline": "We design things and make them come to life.",
#             "location": {
#                "id": "brooklynny",
#                "name": "Brooklyn, NY"
#             },
#             "count": 1
#          },
#          {
#             "id": "universityofiowahealthcare",
#             "name": "University of Iowa Health Care",
#             "url": "https://jobs.uiowa.edu/pands/view/72975",
#             "logo": "https://d2fcz5no062gar.cloudfront.net/assets/images/defaults/company-blank.png",
#             "tagline": "Join our team - a team that is changing medicine and changing lives!",
#             "location": {
#                "id": "iowacityiaus",
#                "name": "Washington, DC",
#                "city": "Iowa City",
#                "country": "US",
#                "lat": "41.6611",
#                "lng": "-91.5302",
#                "state": "IA"
#             },
#             "count": 1
#          },
#          {
#             "id": "vectormediagroup",
#             "name": "Vector Media Group",
#             "url": "http://www.vectormediagroup.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/d72ecaaf7d0db1b80864cd45d84c5b5d/thumb/Vector Logo.jpg",
#             "tagline": "Vector is a full service web development, design, and marketing agency",
#             "location": {
#                "id": "newyorkny",
#                "name": "New York, NY"
#             },
#             "count": 1
#          },
#          {
#             "id": "wearemammoth",
#             "name": "We Are Mammoth",
#             "url": "http://www.WeAreMammoth.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/0c3309ec3d75055b7c6fe93802a699fb/thumb/wam-mark.png",
#             "tagline": null,
#             "location": {
#                "id": "anywhereusa",
#                "name": "Anywhere, USA"
#             },
#             "count": 1
#          },
#          {
#             "id": "whitneymuseumofamericanart",
#             "name": "Whitney Museum of American Art",
#             "url": "http://whitney.org",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/e5e56bfa3ccbdf62fe2d9bdddee915d5/thumb/lh6476RD_400x400.jpeg",
#             "tagline": null,
#             "location": {
#                "id": "newyorknyus",
#                "name": "Washington, DC",
#                "city": "New York",
#                "country": "US",
#                "lat": "40.7143",
#                "lng": "-74.006",
#                "state": "NY"
#             },
#             "count": 1
#          },
#          {
#             "id": "wierstewart",
#             "name": "Wier/Stewart",
#             "url": "http://wierstewart.com",
#             "logo": "https://d2fcz5no062gar.cloudfront.nethttps://authenticjobs.s3.amazonaws.com/uploads/logos/82a4baa9fa5427ba0a2de807c2a3322b/thumb/WS_Logo.jpg",
#             "tagline": "We\u2019re an advertising agency and creative firm in Augusta, Georgia.",
#             "location": {
#                "id": "augustagaus",
#                "name": "Washington, DC",
#                "city": "Augusta",
#                "country": "US",
#                "lat": "33.471",
#                "lng": "-81.9748",
#                "state": "GA"
#             },
#             "count": 1
#          }
#       ],
#       "last_update": "2018-06-27T20:46:49-05:00"
#    },
#    "stat": "ok"
# }

# %%
companies['companies']['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-f8857d2d949b> in <module>()
# ----> 1 companies['companies']['name']
#
# KeyError: 'name'

# %%
params['method'] = 'aj.jobs.getLocations'
location = requests.get(base_url, params).json()
print(json.dumps(location,  indent=3))
# Out:
# {
#    "locations": {
#       "location": [
#          {
#             "id": "alexandriavaus",
#             "name": "Alexandria, VA",
#             "city": "Alexandria, VA",
#             "country": "US",
#             "lat": "38.8048",
#             "lng": "-77.0469",
#             "state": "VA",
#             "count": 1
#          },
#          {
#             "id": "anywhereinunitedstates",
#             "name": "Anywhere in United States",
#             "count": 1
#          },
#          {
#             "id": "anywhereus",
#             "name": "Anywhere (US)",
#             "count": 2
#          },
#          {
#             "id": "anywhereusa",
#             "name": "Anywhere, USA",
#             "count": 1
#          },
#          {
#             "id": "anywhereuscanada",
#             "name": "Anywhere (US/Canada)",
#             "count": 1
#          },
#          {
#             "id": "anywhereusonly",
#             "name": "Anywhere, US only",
#             "count": 1
#          },
#          {
#             "id": "augustagaus",
#             "name": "Augusta, GA",
#             "city": "Augusta, GA",
#             "country": "US",
#             "lat": "33.471",
#             "lng": "-81.9748",
#             "state": "GA",
#             "count": 1
#          },
#          {
#             "id": "austintxus",
#             "name": "Austin, Texas",
#             "city": "Austin, Texas",
#             "country": "US",
#             "lat": "30.2672",
#             "lng": "-97.7431",
#             "state": "TX",
#             "count": 1
#          },
#          {
#             "id": "bellevuewa",
#             "name": "Bellevue, WA",
#             "count": 1
#          },
#          {
#             "id": "bozemanmtus",
#             "name": "Bozeman, Montana",
#             "city": "Bozeman, Montana",
#             "country": "US",
#             "lat": "45.6796",
#             "lng": "-111.039",
#             "state": "MT",
#             "count": 1
#          },
#          {
#             "id": "brooklynny",
#             "name": "Brooklyn, NY",
#             "count": 1
#          },
#          {
#             "id": "cambridgema",
#             "name": "Cambridge, MA",
#             "count": 1
#          },
#          {
#             "id": "charlottesvilleva",
#             "name": "Charlottesville, VA",
#             "count": 2
#          },
#          {
#             "id": "cincinnatiohus",
#             "name": "Cincinnati, OH",
#             "city": "Cincinnati, OH",
#             "country": "US",
#             "lat": "39.1271",
#             "lng": "-84.5144",
#             "state": "OH",
#             "count": 2
#          },
#          {
#             "id": "courtyardbymarriottchicagodowntownilus",
#             "name": "Downtown Chicago",
#             "city": "Downtown Chicago",
#             "country": "US",
#             "lat": "41.89",
#             "lng": "-87.6273",
#             "state": "IL",
#             "count": 1
#          },
#          {
#             "id": "dallastxus",
#             "name": "Dallas, Texas",
#             "city": "Dallas, Texas",
#             "country": "US",
#             "lat": "32.7831",
#             "lng": "-96.8067",
#             "state": "TX",
#             "count": 2
#          },
#          {
#             "id": "denvercous",
#             "name": "Denver, CO",
#             "city": "Denver, CO",
#             "country": "US",
#             "lat": "39.7392",
#             "lng": "-104.985",
#             "state": "CO",
#             "count": 1
#          },
#          {
#             "id": "edmontonabcanada",
#             "name": "Edmonton, AB, Canada",
#             "count": 1
#          },
#          {
#             "id": "iowacityiaus",
#             "name": "Iowa City, IA",
#             "city": "Iowa City, IA",
#             "country": "US",
#             "lat": "41.6611",
#             "lng": "-91.5302",
#             "state": "IA",
#             "count": 1
#          },
#          {
#             "id": "jacksonms",
#             "name": "Jackson, MS",
#             "count": 2
#          },
#          {
#             "id": "kalamazoomius",
#             "name": "Kalamazoo, MI",
#             "city": "Kalamazoo, MI",
#             "country": "US",
#             "lat": "42.2917",
#             "lng": "-85.5872",
#             "state": "MI",
#             "count": 1
#          },
#          {
#             "id": "kingofprussiapaus",
#             "name": "King of Prussia, PA",
#             "city": "King of Prussia, PA",
#             "country": "US",
#             "lat": "40.0893",
#             "lng": "-75.396",
#             "state": "PA",
#             "count": 2
#          },
#          {
#             "id": "londongb",
#             "name": "London",
#             "city": "London",
#             "country": "GB",
#             "lat": "51.5085",
#             "lng": "-0.12574",
#             "count": 1
#          },
#          {
#             "id": "menloparkcaus",
#             "name": "Menlo Park, CA",
#             "city": "Menlo Park, CA",
#             "country": "US",
#             "lat": "37.4538",
#             "lng": "-122.182",
#             "state": "CA",
#             "count": 1
#          },
#          {
#             "id": "munichgermany",
#             "name": "Munich, Germany",
#             "count": 1
#          },
#          {
#             "id": "nashvilletnus",
#             "name": "Nashville, TN",
#             "city": "Nashville, TN",
#             "country": "US",
#             "lat": "36.1659",
#             "lng": "-86.7844",
#             "state": "TN",
#             "count": 2
#          },
#          {
#             "id": "newyorkcity",
#             "name": "New York City",
#             "count": 2
#          },
#          {
#             "id": "newyorkny",
#             "name": "New York, NY",
#             "count": 2
#          },
#          {
#             "id": "newyorknyus",
#             "name": "New York, NY",
#             "city": "New York, NY",
#             "country": "US",
#             "lat": "40.7143",
#             "lng": "-74.006",
#             "state": "NY",
#             "count": 2
#          },
#          {
#             "id": "norfolkva",
#             "name": "Norfolk, VA",
#             "count": 1
#          },
#          {
#             "id": "philadelphiapaus",
#             "name": "Philadelphia, PA",
#             "city": "Philadelphia, PA",
#             "country": "US",
#             "lat": "39.9523",
#             "lng": "-75.1638",
#             "state": "PA",
#             "count": 2
#          },
#          {
#             "id": "raleighnc",
#             "name": "Raleigh, NC",
#             "count": 1
#          },
#          {
#             "id": "rapidcitysdus",
#             "name": "Rapid City, SD",
#             "city": "Rapid City, SD",
#             "country": "US",
#             "lat": "44.0805",
#             "lng": "-103.231",
#             "state": "SD",
#             "count": 1
#          },
#          {
#             "id": "sanfranciscocaus",
#             "name": "San Francisco",
#             "city": "San Francisco",
#             "country": "US",
#             "lat": "37.7749",
#             "lng": "-122.419",
#             "state": "CA",
#             "count": 3
#          },
#          {
#             "id": "seattle",
#             "name": "Seattle",
#             "count": 1
#          },
#          {
#             "id": "seattlewaus",
#             "name": "Seattle",
#             "city": "Seattle",
#             "country": "US",
#             "lat": "47.6062",
#             "lng": "-122.332",
#             "state": "WA",
#             "count": 1
#          },
#          {
#             "id": "sydneyau",
#             "name": "Sydney, Australia",
#             "city": "Sydney, Australia",
#             "country": "AU",
#             "lat": "-33.8679",
#             "lng": "151.207",
#             "count": 1
#          },
#          {
#             "id": "torontoca",
#             "name": "Toronto, Canada",
#             "city": "Toronto, Canada",
#             "country": "CA",
#             "lat": "43.7001",
#             "lng": "-79.4163",
#             "count": 1
#          },
#          {
#             "id": "unitedstates",
#             "name": "United States",
#             "count": 2
#          },
#          {
#             "id": "visaliacaus",
#             "name": "Visalia, CA",
#             "city": "Visalia, CA",
#             "country": "US",
#             "lat": "36.3302",
#             "lng": "-119.292",
#             "state": "CA",
#             "count": 1
#          },
#          {
#             "id": "washingtondc",
#             "name": "Washington, DC",
#             "count": 1
#          },
#          {
#             "id": "washingtondcus",
#             "name": "Washington, DC",
#             "city": "Washington, DC",
#             "country": "US",
#             "lat": "38.8951",
#             "lng": "-77.0364",
#             "state": "DC",
#             "count": 1
#          },
#          {
#             "id": "zrichswitzerland",
#             "name": "Z\u00fcrich, Switzerland",
#             "count": 1
#          }
#       ],
#       "last_update": "2018-06-27T20:46:49-05:00"
#    },
#    "stat": "ok"
# }

# %%
params['method'] = 'aj.jobs.get'
jobs = requests.get(base_url, params).json()
print(json.dumps(jobs,  indent=3))
# Out:
# {
#    "stat": "fail",
#    "code": 6,
#    "desc": "Invalid parameters: 'id' is required"
# }

# %%
https://authenticjobs.com/api/?api_key=a446a0eefe6f5699283g34f4d5b51fa0&method=aj.jobs.get&id=1569
